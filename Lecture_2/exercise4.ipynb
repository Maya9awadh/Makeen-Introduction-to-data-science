# %% [raw]
# Create a list of 100 random pair of integers (x,y) between 1 and 100. Draw visualization
# of the data using different

# %%
#imported library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame(np.random.randint(0,100,size=(100, 2)), columns=list('xy'))
print(df.head())
# Out:
#     x   y
# 0  55  78
# 1  65  49
# 2  57  89
# 3  35  83
# 4  79  23

# %%
#draw scatter plot
plt.scatter(df['x'],df['y'])
plt.show()

# %% [raw]
# #from the plot above, we can see that there is no correlation between x and y.
